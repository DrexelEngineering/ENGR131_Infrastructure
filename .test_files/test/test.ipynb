# %%
import pandas as pd
import json
from datetime import datetime, timedelta
import pytz

def lab_csv_to_json(file_path, section_id, day_of_week, start_time):
    
    # Read the CSV file
    data = pd.read_csv(file_path)

    # Preparing the JSON structure
    lab_json = []
    for index, row in data.iterrows():
        student_record_template = {
            "student_id": 0,  # Integer
            "lastname": "",  # Character varying(255)
            "firstname": "",  # Character varying(255)
            "middlename": "",  # Character varying(255)
            "levelname": "",  # Character varying(255)
            "classificationname": "",  # Character varying(255)
            "majorname": "",  # Character varying(255)
            "emailaddress": "",  # Character varying(255)
            "userid": "",  # Character varying(255)
            "zoomid": "",  # Character varying(255)
            "sectionnumber": 0,  # Integer
            "starttime": None,  # Time with time zone, placeholder None for datetime.time or similar
            "endtime": None,  # Time with time zone, placeholder None for datetime.time or similar
            "day_of_week": "",  # Text
        }
    #     students_json.append(student_info)
        
    # Return the JSON data
    return data

# %%
# Specify the path to your .xls file
file_path = "/Users/joshuaagar/code/K8_autograder_database/.test_files/test/ENGR131-060.csv"

# Read the .xls file as a dictionary
xls_data_dict = lab_csv_to_json(file_path, "060", "Monday", "10:00")

# %%
xls_data_dict
# Out:
#     studentId      lastName  firstName middleName      levelname  \
# 0    14622283           Ali       Asad        NaN  Undergraduate
# 1    14665387        Bayram       Omer        NaN  Undergraduate
# 2    14636373          Chen    Matthew        NaN  Undergraduate
# 3    14677698       Collins       Ryan          D  Undergraduate
# 4    14637206         Corle     Justin    Timothy  Undergraduate
# 5    14624893         Davis    Miranda       Rose  Undergraduate
# 6    14657965          Diaz       Owen    Orlando  Undergraduate
# 7    14632554     DiPrinzio       Dean    Patrick  Undergraduate
# 8    14650711         Diver    Nichole       Anne  Undergraduate
# 9    14630511   Dobrowolski     Andrew          M  Undergraduate
# 10   14670706       Doughty       Emma     Cooper  Undergraduate
# 11   14630322       Fischer   Leighton  Frederick  Undergraduate
# 12   14656249        Flynne       Sean    Russell  Undergraduate
# ...
